# %% [markdown]
# <a href="https://colab.research.google.com/github/cybersam9/cybersam9/blob/main/bargraphvisualization(complite).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

x=['A','B','C','D','E']
y=[10,20,15,4,54]
color=['red','green','gold','pink','yellow']
plt.figure(figsize=(10,5))

plt.bar(x,y,color=colors)
plt.title("whatsapp me: 0726149592")
plt.xlabel("samson")
plt.ylabel("musyoka")
plt.grid(True)
plt.show()
